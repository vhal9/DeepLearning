# %% [markdown]
# ### Classificação multiclasse para a base de plantas de íris

# %%
import pandas as pd

# %% [markdown]
# ### Carregar os dados

# %%
base = pd.read_csv('../../data/base iris/iris.csv')

# %% [markdown]
# - Extração dos atributos previsores e das classes

# %%
previsores = base.iloc[:, 0:4].values
classe = base.iloc[:, 4].values

# %%
base[:3]
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
previsores[:3]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2]])

# %% [markdown]
# ### Transformação das classes para valores numéricos e categóricos

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
classe = labelencoder.fit_transform(classe)

# %%
from keras.utils import np_utils
classe_dummy = np_utils.to_categorical(classe)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Divisão da base em treinamento e teste
# - 25% para teste e 75% para treinamento

# %%
from sklearn.model_selection import train_test_split

# %%
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe_dummy, test_size=0.25)

# %% [markdown]
# ### Estrutura da rede neural

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
classificador = Sequential()
classificador.add(Dense(units=4, activation='relu', input_dim=4))
classificador.add(Dense(units=4, activation='relu'))
classificador.add(Dense(units=3, activation = 'softmax'))
classificador.compile(optimizer = 'adam', loss= 'categorical_crossentropy', metrics=['categorical_accuracy'])

# %% [markdown]
# - Treinamento

# %%
classificador.fit(previsores_treinamento, classe_treinamento, batch_size=10, epochs=1000)
# Out:
# Epoch 1/1000
# 112/112 [==============================] - 2s 17ms/step - loss: 2.5291 - categorical_accuracy: 0.3214
# Epoch 2/1000
# 112/112 [==============================] - 0s 627us/step - loss: 2.3241 - categorical_accuracy: 0.3214
# Epoch 3/1000
# 112/112 [==============================] - 0s 871us/step - loss: 2.1373 - categorical_accuracy: 0.3214
# Epoch 4/1000
# 112/112 [==============================] - 0s 764us/step - loss: 1.9791 - categorical_accuracy: 0.3214
# Epoch 5/1000
# 112/112 [==============================] - 0s 716us/step - loss: 1.8467 - categorical_accuracy: 0.3214
# Epoch 6/1000
# 112/112 [==============================] - 0s 919us/step - loss: 1.7270 - categorical_accuracy: 0.3214
# Epoch 7/1000
# 112/112 [==============================] - 0s 607us/step - loss: 1.6233 - categorical_accuracy: 0.3214
# Epoch 8/1000
# 112/112 [==============================] - 0s 756us/step - loss: 1.5273 - categorical_accuracy: 0.3214
# Epoch 9/1000
# ...

# %% [markdown]
# ### Predição para a base de teste

# %%
resultado = classificador.evaluate(previsores_teste, classe_teste)
previsoes = classificador.predict(previsores_teste)
# Out:
# 38/38 [==============================] - 0s 2ms/step

# %% [markdown]
# ### Resultados

# %%
resultado
# Out:
# [0.04611648579961375, 1.0]

# %%
previsoes>0.5
# Out:
# array([[False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
# ...

# %%
import numpy as np
classe_teste2 = [np.argmax(t) for t in classe_teste]
previsoes2 = [np.argmax(t) for t in previsoes]

# %% [markdown]
# ### Matriz de confusão

# %%
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(previsoes2, classe_teste2)

# %%
matriz
# Out:
# array([[15,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 14]])
