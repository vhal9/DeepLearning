# %% [markdown]
# ### Aplicação de Tuning para os parâmetros de erros

# %% [markdown]
# #### Importar base de dados que foi processada anteriormente

# %%
import pandas as pd

# %%
# base produzida a partir da limpeza no primeiro exemplo
base = pd.read_csv('../../data/baseCarrosProcessada.csv', encoding = 'ISO-8859-1')

# %%
base[:10]
# Out:
#    Unnamed: 0  price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0           0    480     test   limousine                1993    manuell
# 1           1  18300     test       coupe                2011    manuell
# 2           2   9800     test         suv                2004  automatik
# 3           3   1500     test  kleinwagen                2001    manuell
# 4           4   3600     test  kleinwagen                2008    manuell
# 5           5    650     test   limousine                1995    manuell
# 6           6   2200     test      cabrio                2004    manuell
# 7           8  14500  control         bus                2014    manuell
# 8           9    999     test  kleinwagen                1998    manuell
# 9          10   2000  control   limousine                2004    manuell
#
#    powerPS    model  kilometer  monthOfRegistration fuelType       brand  \
# 0        0     golf     150000                    0   benzin  volkswagen
# 1      190     golf     125000                    5   diesel        audi
# 2      163    grand     125000                    8   diesel        jeep
# 3       75     golf     150000                    6   benzin  volkswagen
# 4       69    fabia      90000                    7   diesel       skoda
# 5      102      3er     150000                   10   benzin         bmw
# 6      109  2_reihe     150000                    8   benzin     peugeot
# 7      125    c_max      30000                    8   benzin        ford
# 8      101     golf     150000                    0   benzin  volkswagen
# 9      105  3_reihe     150000                   12   benzin       mazda
#
#   notRepairedDamage
# 0              nein
# 1                ja
# 2              nein
# 3              nein
# 4              nein
# 5                ja
# 6              nein
# 7              nein
# 8              nein
# 9              nein

# %% [markdown]
# ### Remover a coluna de index gerada anteriormente

# %%
base = base.drop('Unnamed: 0', axis=1)

# %%
base
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test   limousine                1993    manuell        0
# 1       18300     test       coupe                2011    manuell      190
# 2        9800     test         suv                2004  automatik      163
# 3        1500     test  kleinwagen                2001    manuell       75
# 4        3600     test  kleinwagen                2008    manuell       69
# 5         650     test   limousine                1995    manuell      102
# 6        2200     test      cabrio                2004    manuell      109
# 7       14500  control         bus                2014    manuell      125
# 8         999     test  kleinwagen                1998    manuell      101
# 9        2000  control   limousine                2004    manuell      105
# 10       2799  control       kombi                2005    manuell      140
# 11        999  control       kombi                1995    manuell      115
# 12       2500  control       kombi                2004    manuell      131
# 13      17999  control         suv                2011    manuell      190
# 14        450     test  kleinwagen                1910    manuell        0
# 15        300     test   limousine                2016    manuell       60
# 16       1750  control  kleinwagen                2004  automatik       75
# 17       7550     test         bus                2007    manuell      136
# 18       1850     test         bus                2004    manuell      102
# 19      10400  control       coupe                2009    manuell      160
# 20       3699     test   limousine                2002  automatik      231
# 21       2900     test   limousine                2018    manuell       90
# 22        450     test  kleinwagen                1997    manuell       50
# 23        500     test   limousine                1990    manuell      118
# 24       2500  control       kombi                2002  automatik      193
# 25       5555  control   limousine                2017    manuell      125
# 26       6900     test   limousine                2008    manuell       99
# 27       1990     test         bus                1981    manuell       50
# 28        690     test  kleinwagen                2003    manuell       60
# 29       3300     test   limousine                1995  automatik      113
# ...       ...      ...         ...                 ...        ...      ...
# 359261   4900  control       kombi                2008    manuell      116
# 359262    699  control   limousine                1999    manuell      101
# 359263    600  control  kleinwagen                1998    manuell       54
# 359264  20400     test   limousine                2014  automatik      150
# 359265   3900     test         bus                2003  automatik      174
# 359266   1600     test       kombi                1998    manuell      125
# 359267   1700  control  kleinwagen                1999    manuell       68
# 359268   2600  control   limousine                2005  automatik        0
# 359269    800     test       kombi                2000    manuell      101
# 359270   5900     test   limousine                2006    manuell      105
# 359271   5999     test       kombi                2005    manuell      140
# 359272   1400  control   limousine                2001    manuell      125
# 359273   1900     test   limousine                2000    manuell      110
# 359274   6500     test   limousine                2003  automatik      145
# 359275   1999  control   limousine                1997    manuell      150
# 359276   5000     test   limousine                2003  automatik      260
# 359277   4400  control   limousine                2008    manuell      105
# 359278    999  control      cabrio                2000    manuell       95
# 359279   1690     test       kombi                2004    manuell       55
# 359280   1490  control  kleinwagen                1998    manuell       50
# 359281   7900     test   limousine                2010    manuell      140
# 359282   3999     test       kombi                2005    manuell        3
# 359283   5250  control   limousine                2016  automatik      150
# 359284   3200  control   limousine                2004    manuell      225
# 359285   1150  control         bus                2000    manuell        0
# 359286   2200     test   limousine                2005    manuell        0
# 359287   1199     test      cabrio                2000  automatik      101
# 359288   9200     test         bus                1996    manuell      102
# 359289   3400     test       kombi                2002    manuell      100
# 359290  28990  control   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 0              golf     150000                    0   benzin      volkswagen
# 1              golf     125000                    5   diesel            audi
# 2             grand     125000                    8   diesel            jeep
# 3              golf     150000                    6   benzin      volkswagen
# 4             fabia      90000                    7   diesel           skoda
# 5               3er     150000                   10   benzin             bmw
# 6           2_reihe     150000                    8   benzin         peugeot
# 7             c_max      30000                    8   benzin            ford
# 8              golf     150000                    0   benzin      volkswagen
# 9           3_reihe     150000                   12   benzin           mazda
# 10           passat     150000                   12   diesel      volkswagen
# 11           passat     150000                   11   benzin      volkswagen
# 12           passat     150000                    2   benzin      volkswagen
# 13           navara      70000                    3   diesel          nissan
# 14               ka       5000                    0   benzin            ford
# 15             polo     150000                    0   benzin      volkswagen
# 16           twingo     150000                    2   benzin         renault
# 17            c_max     150000                    6   diesel            ford
# 18         a_klasse     150000                    1   benzin   mercedes_benz
# 19         scirocco     100000                    4   benzin      volkswagen
# 20              5er     150000                    7   benzin             bmw
# 21           meriva     150000                    5   benzin            opel
# 22            arosa     150000                    5   benzin            seat
# 23           andere     150000                   10   benzin   mercedes_benz
# 24              5er     150000                    9   diesel             bmw
# 25               c4     125000                    4   benzin         citroen
# 26            civic      60000                   11   benzin           honda
# 27      transporter       5000                    1   benzin      volkswagen
# 28            punto     150000                    3   benzin            fiat
# 29         e_klasse     150000                    1   diesel   mercedes_benz
# ...             ...        ...                  ...      ...             ...
# 359261        astra     150000                    2   benzin            opel
# 359262       vectra     150000                    3   benzin            opel
# 359263        corsa     150000                    1   benzin            opel
# 359264         golf      30000                    9   benzin      volkswagen
# 359265      voyager     150000                    7   benzin        chrysler
# 359266           a4     150000                    2   benzin            audi
# 359267        justy      70000                   11   benzin          subaru
# 359268     c_klasse     150000                    9   benzin   mercedes_benz
# 359269        astra     150000                   11   benzin            opel
# 359270         golf     150000                    9   diesel      volkswagen
# 359271           a4     150000                    4   diesel            audi
# 359272        astra     150000                    2   benzin            opel
# 359273         golf     150000                    7   benzin      volkswagen
# 359274     e_klasse     150000                    3   diesel   mercedes_benz
# 359275           a3     150000                   12   benzin            audi
# 359276     e_klasse     150000                   12   diesel   mercedes_benz
# 359277         leon     150000                    7   diesel            seat
# 359278       megane     150000                    4   benzin         renault
# 359279        fabia     150000                    4   benzin           skoda
# 359280         lupo     150000                    9   benzin      volkswagen
# 359281         golf     150000                    7   diesel      volkswagen
# 359282          3er     150000                    5   diesel             bmw
# 359283          159     150000                   12   benzin      alfa_romeo
# 359284         leon     150000                    5   benzin            seat
# 359285       zafira     150000                    3   benzin            opel
# 359286         golf      20000                    1   benzin  sonstige_autos
# 359287       fortwo     125000                    3   benzin           smart
# 359288  transporter     150000                    3   diesel      volkswagen
# 359289         golf     150000                    6   diesel      volkswagen
# 359290      m_reihe      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 0                   nein
# 1                     ja
# 2                   nein
# 3                   nein
# 4                   nein
# 5                     ja
# 6                   nein
# 7                   nein
# 8                   nein
# 9                   nein
# 10                    ja
# 11                  nein
# 12                  nein
# 13                  nein
# 14                  nein
# 15                  nein
# 16                  nein
# 17                  nein
# 18                  nein
# 19                  nein
# 20                  nein
# 21                  nein
# 22                  nein
# 23                    ja
# 24                    ja
# 25                  nein
# 26                  nein
# 27                  nein
# 28                  nein
# 29                  nein
# ...                  ...
# 359261              nein
# 359262              nein
# 359263              nein
# 359264              nein
# 359265              nein
# 359266              nein
# 359267              nein
# 359268              nein
# 359269                ja
# 359270              nein
# 359271              nein
# 359272              nein
# 359273              nein
# 359274              nein
# 359275              nein
# 359276                ja
# 359277              nein
# 359278              nein
# 359279              nein
# 359280              nein
# 359281              nein
# 359282              nein
# 359283              nein
# 359284                ja
# 359285              nein
# 359286              nein
# 359287              nein
# 359288              nein
# 359289              nein
# 359290              nein
#
# [359291 rows x 12 columns]

# %% [markdown]
# ### Extrair dados para treinamento predição e os dados da classe (preço real)

# %%
previsores = base.iloc[:, 1:13].values

# %%
preco_real = base.iloc[:, 0].values

# %% [markdown]
# ### Transformação dos dados

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelEncoder_previsores = LabelEncoder()

# %%
previsores[:,0] = labelEncoder_previsores.fit_transform(previsores[:,0])
previsores[:,1] = labelEncoder_previsores.fit_transform(previsores[:,1])
previsores[:,3] = labelEncoder_previsores.fit_transform(previsores[:,3])
previsores[:,5] = labelEncoder_previsores.fit_transform(previsores[:,5])
previsores[:,8] = labelEncoder_previsores.fit_transform(previsores[:,8])
previsores[:,9] = labelEncoder_previsores.fit_transform(previsores[:,9])
previsores[:,10] = labelEncoder_previsores.fit_transform(previsores[:,10])

# %% [markdown]
# ## Categorização

# %%
from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer([("", OneHotEncoder(),[0,1,3,5,8,9,10])], remainder="passthrough") 
previsores = ct.fit_transform(previsores)

# %% [markdown]
# ### Criação da Rede

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
# Out:
# Using TensorFlow backend.

# %%
def criarRede(loss):
    regressor = Sequential()
    regressor.add(Dense(units = 158, activation='relu', input_dim=316))
    regressor.add(Dropout(0.2))
    regressor.add(Dense(units = 158, activation='relu'))
    regressor.add(Dropout(0.2))
    regressor.add(Dense(units = 1, activation='linear'))
    regressor.compile(loss = loss, optimizer='adam', metrics = ['mean_absolute_error'])
    return regressor

# %% [markdown]
# #### Parâmetros que serão testados

# %%
regressor = KerasRegressor(build_fn = criarRede, batch_size = 300, epochs=100, verbose=0)
parametros = {'loss': ['mean_squared_error', 'mean_absolute_error',
                       'mean_absolute_percentage_error', 'mean_squared_logarithmic_error',
                       'squared_hinge']}
grid_search = GridSearchCV(estimator = regressor,
                           param_grid = parametros,
                           cv = 10)

# %% [markdown]
# #### Teste dos parâmetros

# %%
grid_search = grid_search.fit(previsores, preco_real)

# %%
melhores_parametros = grid_search.best_params_

# %%
melhores_precisao = grid_search.best_score_

# %%
print(melhores_parametros, melhores_precisao)
# Out:
# {'loss': 'squared_hinge'} 0.0
