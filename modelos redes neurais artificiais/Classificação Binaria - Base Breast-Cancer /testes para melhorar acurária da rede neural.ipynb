# %% [markdown]
# ### Testes para melhorar acurácia do modelo para base de cancer de mama

# %%
import keras
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Atencao ao diretorio dos arquivos

# %%
previsores = pd.read_csv('../../data/base breast cancer/entradas-breast.csv')
classe = pd.read_csv('../../data/base breast cancer/saidas-breast.csv')

# %%
previsores[:10]
# Out:
#     radius_mean   texture_mean   perimeter_mean   area_mean   smoothness_mean  \
# 0         17.99          10.38           122.80      1001.0           0.11840
# 1         20.57          17.77           132.90      1326.0           0.08474
# 2         19.69          21.25           130.00      1203.0           0.10960
# 3         11.42          20.38            77.58       386.1           0.14250
# 4         20.29          14.34           135.10      1297.0           0.10030
# 5         12.45          15.70            82.57       477.1           0.12780
# 6         18.25          19.98           119.60      1040.0           0.09463
# 7         13.71          20.83            90.20       577.9           0.11890
# 8         13.00          21.82            87.50       519.8           0.12730
# 9         12.46          24.04            83.97       475.9           0.11860
#
#     compactness_mean   concavity_mean  concave_points_mean   symmetry_mean  \
# ...

# %% [markdown]
# ### Rede inicial

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)

# %%
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 3ms/step - loss: 1.5021 - binary_accuracy: 0.5859
# Epoch 2/100
# 512/512 [==============================] - 0s 235us/step - loss: 0.6411 - binary_accuracy: 0.6777
# Epoch 3/100
# 512/512 [==============================] - 0s 204us/step - loss: 0.5932 - binary_accuracy: 0.6738
# Epoch 4/100
# 512/512 [==============================] - 0s 223us/step - loss: 0.5994 - binary_accuracy: 0.6660
# Epoch 5/100
# 512/512 [==============================] - 0s 227us/step - loss: 0.6175 - binary_accuracy: 0.6719
# Epoch 6/100
# 512/512 [==============================] - 0s 218us/step - loss: 0.5879 - binary_accuracy: 0.6797
# Epoch 7/100
# 512/512 [==============================] - 0s 204us/step - loss: 0.5928 - binary_accuracy: 0.6719
# Epoch 8/100
# 512/512 [==============================] - 0s 224us/step - loss: 0.6211 - binary_accuracy: 0.6758
# Epoch 9/100
# ...

# %%
media = resultados.mean()

# %%
desvio = resultados.std()

# %%
media
# Out:
# 0.8613095238095237

# %%
desvio
# Out:
# 0.07492226050213151

# %% [markdown]
# ## Primeiro teste:
#  - Mais camadas na rede neural
#  - 4 camadas ocultas

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)

# %%
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6418 - binary_accuracy: 0.6699
# Epoch 2/100
# 512/512 [==============================] - 0s 284us/step - loss: 0.5820 - binary_accuracy: 0.6934
# Epoch 3/100
# 512/512 [==============================] - 0s 264us/step - loss: 0.5447 - binary_accuracy: 0.6758
# Epoch 4/100
# 512/512 [==============================] - 0s 269us/step - loss: 0.5256 - binary_accuracy: 0.7344
# Epoch 5/100
# 512/512 [==============================] - 0s 264us/step - loss: 0.4948 - binary_accuracy: 0.7676
# Epoch 6/100
# 512/512 [==============================] - 0s 254us/step - loss: 0.4630 - binary_accuracy: 0.7832
# Epoch 7/100
# 512/512 [==============================] - 0s 291us/step - loss: 0.4513 - binary_accuracy: 0.7949
# Epoch 8/100
# 512/512 [==============================] - 0s 268us/step - loss: 0.4215 - binary_accuracy: 0.8262
# Epoch 9/100
# ...

# %%
print(resultados.mean())
# Out:
# 0.8699874686716791

# %%
print(resultados.std())
# Out:
# 0.08773865253724022

# %% [markdown]
# ## Segundo Teste
# - número diferente de neuronios nas camadas

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6615 - binary_accuracy: 0.6250
# Epoch 2/100
# 512/512 [==============================] - 0s 370us/step - loss: 0.5515 - binary_accuracy: 0.6836
# Epoch 3/100
# 512/512 [==============================] - 0s 359us/step - loss: 0.5145 - binary_accuracy: 0.7090
# Epoch 4/100
# 512/512 [==============================] - 0s 288us/step - loss: 0.5167 - binary_accuracy: 0.7285
# Epoch 5/100
# 512/512 [==============================] - 0s 394us/step - loss: 0.4913 - binary_accuracy: 0.7578
# Epoch 6/100
# 512/512 [==============================] - 0s 316us/step - loss: 0.4566 - binary_accuracy: 0.7871
# Epoch 7/100
# 512/512 [==============================] - 0s 296us/step - loss: 0.4666 - binary_accuracy: 0.7891
# Epoch 8/100
# 512/512 [==============================] - 0s 328us/step - loss: 0.4499 - binary_accuracy: 0.8477
# Epoch 9/100
# ...

# %%
print(resultados.mean())
# Out:
# 0.892825814536341

# %%
print(resultados.std())
# Out:
# 0.06989213563764562

# %% [markdown]
# ### Terceiro teste:
# - diminuir ou aumentar o dropout das camadas

# %% [markdown]
# - Parte 1/2

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.1875))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1875))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1875))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.125))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6336 - binary_accuracy: 0.6797
# Epoch 2/100
# 512/512 [==============================] - 0s 288us/step - loss: 0.5549 - binary_accuracy: 0.7617
# Epoch 3/100
# 512/512 [==============================] - 0s 281us/step - loss: 0.5241 - binary_accuracy: 0.6836
# Epoch 4/100
# 512/512 [==============================] - 0s 284us/step - loss: 0.5193 - binary_accuracy: 0.7090
# Epoch 5/100
# 512/512 [==============================] - 0s 289us/step - loss: 0.4874 - binary_accuracy: 0.7168
# Epoch 6/100
# 512/512 [==============================] - 0s 299us/step - loss: 0.4777 - binary_accuracy: 0.7480
# Epoch 7/100
# 512/512 [==============================] - 0s 307us/step - loss: 0.4638 - binary_accuracy: 0.7891
# Epoch 8/100
# 512/512 [==============================] - 0s 289us/step - loss: 0.4184 - binary_accuracy: 0.8105
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.8857769423558898
# 0.06383727889836101

# %% [markdown]
# - Parte 2/2

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6435 - binary_accuracy: 0.6719
# Epoch 2/100
# 512/512 [==============================] - 0s 301us/step - loss: 0.5765 - binary_accuracy: 0.6953
# Epoch 3/100
# 512/512 [==============================] - 0s 283us/step - loss: 0.5360 - binary_accuracy: 0.6895
# Epoch 4/100
# 512/512 [==============================] - 0s 293us/step - loss: 0.4922 - binary_accuracy: 0.7344
# Epoch 5/100
# 512/512 [==============================] - 0s 362us/step - loss: 0.5281 - binary_accuracy: 0.7344
# Epoch 6/100
# 512/512 [==============================] - 0s 280us/step - loss: 0.4545 - binary_accuracy: 0.7891
# Epoch 7/100
# 512/512 [==============================] - 0s 294us/step - loss: 0.4341 - binary_accuracy: 0.7891
# Epoch 8/100
# 512/512 [==============================] - 0s 299us/step - loss: 0.4499 - binary_accuracy: 0.8066
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.9051378446115288
# 0.05770959013881478

# %% [markdown]
# ### Melhor configuração até agora: Terceiro Teste part 2/2.

# %% [markdown]
# ### Quarto Teste: Testar outras funções de ativação
# - 1º: Função tanh

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'tanh', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'tanh', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'tanh', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'tanh', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6655 - binary_accuracy: 0.6660
# Epoch 2/100
# 512/512 [==============================] - 0s 295us/step - loss: 0.6134 - binary_accuracy: 0.6758
# Epoch 3/100
# 512/512 [==============================] - 0s 283us/step - loss: 0.5776 - binary_accuracy: 0.6973
# Epoch 4/100
# 512/512 [==============================] - 0s 310us/step - loss: 0.5355 - binary_accuracy: 0.7168
# Epoch 5/100
# 512/512 [==============================] - 0s 277us/step - loss: 0.5533 - binary_accuracy: 0.7031
# Epoch 6/100
# 512/512 [==============================] - 0s 285us/step - loss: 0.5734 - binary_accuracy: 0.7305
# Epoch 7/100
# 512/512 [==============================] - 0s 284us/step - loss: 0.5653 - binary_accuracy: 0.7383
# Epoch 8/100
# 512/512 [==============================] - 0s 295us/step - loss: 0.5042 - binary_accuracy: 0.7656
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.7751253132832079
# 0.0892202635717504

# %% [markdown]
# - 2º: função exp

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'exponential', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'exponential', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'exponential', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'exponential', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: nan - binary_accuracy: 0.0000e+00
# Epoch 2/100
# 512/512 [==============================] - 0s 269us/step - loss: nan - binary_accuracy: 0.0000e+00
# Epoch 3/100
# 512/512 [==============================] - 0s 276us/step - loss: nan - binary_accuracy: 0.0000e+00
# Epoch 4/100
# 512/512 [==============================] - 0s 304us/step - loss: nan - binary_accuracy: 0.0000e+00
# Epoch 5/100
# 512/512 [==============================] - ETA: 0s - loss: nan - binary_accuracy: 0.0000e+ - 0s 290us/step - loss: nan - binary_accuracy: 0.0000e+00
# Epoch 6/100
# 512/512 [==============================] - 0s 345us/step - loss: nan - binary_accuracy: 0.0000e+00
# Epoch 7/100
# 512/512 [==============================] - 0s 277us/step - loss: nan - binary_accuracy: 0.0000e+00
# Epoch 8/100
# 512/512 [==============================] - 0s 301us/step - loss: nan - binary_accuracy: 0.0000e+00
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.3723370927318295
# 0.1769967089453397

# %% [markdown]
# - 3º: Função elu

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'elu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'elu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'elu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'elu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6179 - binary_accuracy: 0.6875
# Epoch 2/100
# 512/512 [==============================] - 0s 387us/step - loss: 0.5529 - binary_accuracy: 0.7168
# Epoch 3/100
# 512/512 [==============================] - 0s 426us/step - loss: 0.4866 - binary_accuracy: 0.7793
# Epoch 4/100
# 512/512 [==============================] - 0s 411us/step - loss: 0.4437 - binary_accuracy: 0.7988
# Epoch 5/100
# 512/512 [==============================] - 0s 432us/step - loss: 0.4054 - binary_accuracy: 0.8203
# Epoch 6/100
# 512/512 [==============================] - 0s 415us/step - loss: 0.3800 - binary_accuracy: 0.8340
# Epoch 7/100
# 512/512 [==============================] - 0s 455us/step - loss: 0.3621 - binary_accuracy: 0.8555
# Epoch 8/100
# 512/512 [==============================] - 0s 403us/step - loss: 0.3446 - binary_accuracy: 0.8613
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.8979636591478697
# 0.059403990009045615

# %% [markdown]
# #### Terceiro teste continua sendo o melhor ate aqui

# %% [markdown]
# ### Quinto Teste: Testar outras formas de inicialização
# - 1º: Zeros
# - 2º: Normal
# - 3º: VarianceScaling
# - 4º: Orthogonal
# - 5º: Ones

# %% [markdown]
# - 1º: Zeros

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'zeros', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'zeros'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'zeros'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'zeros'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6900 - binary_accuracy: 0.6641
# Epoch 2/100
# 512/512 [==============================] - 0s 273us/step - loss: 0.6835 - binary_accuracy: 0.6758
# Epoch 3/100
# 512/512 [==============================] - 0s 290us/step - loss: 0.6776 - binary_accuracy: 0.6758
# Epoch 4/100
# 512/512 [==============================] - 0s 303us/step - loss: 0.6726 - binary_accuracy: 0.6758
# Epoch 5/100
# 512/512 [==============================] - 0s 361us/step - loss: 0.6679 - binary_accuracy: 0.6758
# Epoch 6/100
# 512/512 [==============================] - 0s 427us/step - loss: 0.6638 - binary_accuracy: 0.6758
# Epoch 7/100
# 512/512 [==============================] - 0s 506us/step - loss: 0.6603 - binary_accuracy: 0.6758
# Epoch 8/100
# 512/512 [==============================] - 0s 370us/step - loss: 0.6571 - binary_accuracy: 0.6758
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.6276629072681705
# 0.1769967089453397

# %% [markdown]
# - 2º: normal

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'normal', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'normal'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'normal'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'normal'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6515 - binary_accuracy: 0.6328
# Epoch 2/100
# 512/512 [==============================] - 0s 260us/step - loss: 0.5697 - binary_accuracy: 0.6504
# Epoch 3/100
# 512/512 [==============================] - 0s 263us/step - loss: 0.5578 - binary_accuracy: 0.6699
# Epoch 4/100
# 512/512 [==============================] - 0s 267us/step - loss: 0.5215 - binary_accuracy: 0.7012
# Epoch 5/100
# 512/512 [==============================] - 0s 268us/step - loss: 0.4896 - binary_accuracy: 0.7832
# Epoch 6/100
# 512/512 [==============================] - 0s 275us/step - loss: 0.4542 - binary_accuracy: 0.7930
# Epoch 7/100
# 512/512 [==============================] - 0s 273us/step - loss: 0.4560 - binary_accuracy: 0.8066
# Epoch 8/100
# 512/512 [==============================] - 0s 271us/step - loss: 0.4441 - binary_accuracy: 0.7930
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.8946741854636591
# 0.06557636447314855

# %% [markdown]
# - 3º: VarianceScaling

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'VarianceScaling', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'VarianceScaling'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'VarianceScaling'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'VarianceScaling'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador

classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 29.8028 - binary_accuracy: 0.5684
# Epoch 2/100
# 512/512 [==============================] - 0s 334us/step - loss: 11.7203 - binary_accuracy: 0.5586
# Epoch 3/100
# 512/512 [==============================] - 0s 307us/step - loss: 5.2618 - binary_accuracy: 0.6074
# Epoch 4/100
# 512/512 [==============================] - 0s 268us/step - loss: 5.1631 - binary_accuracy: 0.6270
# Epoch 5/100
# 512/512 [==============================] - 0s 309us/step - loss: 2.9928 - binary_accuracy: 0.5801
# Epoch 6/100
# 512/512 [==============================] - 0s 277us/step - loss: 1.9079 - binary_accuracy: 0.5645
# Epoch 7/100
# 512/512 [==============================] - 0s 291us/step - loss: 1.9955 - binary_accuracy: 0.6328
# Epoch 8/100
# 512/512 [==============================] - 0s 283us/step - loss: 1.8166 - binary_accuracy: 0.5898
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.819204260651629
# 0.17781897760959914

# %% [markdown]
# - 4º: Orthogonal

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'orthogonal', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'orthogonal'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'orthogonal'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'orthogonal'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 16.5774 - binary_accuracy: 0.5723
# Epoch 2/100
# 512/512 [==============================] - 0s 279us/step - loss: 5.5345 - binary_accuracy: 0.5000
# Epoch 3/100
# 512/512 [==============================] - 0s 321us/step - loss: 2.3905 - binary_accuracy: 0.5156
# Epoch 4/100
# 512/512 [==============================] - 0s 326us/step - loss: 2.4311 - binary_accuracy: 0.4570
# Epoch 5/100
# 512/512 [==============================] - 0s 328us/step - loss: 1.5560 - binary_accuracy: 0.5410
# Epoch 6/100
# 512/512 [==============================] - 0s 331us/step - loss: 1.4951 - binary_accuracy: 0.6582
# Epoch 7/100
# 512/512 [==============================] - 0s 296us/step - loss: 1.1970 - binary_accuracy: 0.6582
# Epoch 8/100
# 512/512 [==============================] - 0s 345us/step - loss: 1.3763 - binary_accuracy: 0.6602
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.6908208020050126
# 0.15928363668519147

# %% [markdown]
# - 5º: Ones

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'ones', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'ones'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'ones'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'ones'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 5826645.9169 - binary_accuracy: 0.5742
# Epoch 2/100
# 512/512 [==============================] - 0s 281us/step - loss: 5893959.7131 - binary_accuracy: 0.5254
# Epoch 3/100
# 512/512 [==============================] - 0s 282us/step - loss: 4636552.2568 - binary_accuracy: 0.5254
# Epoch 4/100
# 512/512 [==============================] - 0s 282us/step - loss: 3658232.4289 - binary_accuracy: 0.5332
# Epoch 5/100
# 512/512 [==============================] - 0s 291us/step - loss: 3272382.7791 - binary_accuracy: 0.4863 0s - loss: 3172684.5236 - binary_accuracy: 0.494
# Epoch 6/100
# 512/512 [==============================] - 0s 306us/step - loss: 1999822.4968 - binary_accuracy: 0.5371
# Epoch 7/100
# 512/512 [==============================] - 0s 294us/step - loss: 1576536.1427 - binary_accuracy: 0.5273
# Epoch 8/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.6276629072681705
# 0.1769967089453397

# %% [markdown]
# - 6º: random normal

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'random_normal', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_normal'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_normal'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'random_normal'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 2ms/step - loss: 0.6241 - binary_accuracy: 0.6270
# Epoch 2/100
# 512/512 [==============================] - 0s 476us/step - loss: 0.5742 - binary_accuracy: 0.6699
# Epoch 3/100
# 512/512 [==============================] - 0s 438us/step - loss: 0.5306 - binary_accuracy: 0.7422
# Epoch 4/100
# 512/512 [==============================] - 0s 443us/step - loss: 0.4846 - binary_accuracy: 0.7559
# Epoch 5/100
# 512/512 [==============================] - 0s 485us/step - loss: 0.5042 - binary_accuracy: 0.7598
# Epoch 6/100
# 512/512 [==============================] - 0s 479us/step - loss: 0.4954 - binary_accuracy: 0.7578
# Epoch 7/100
# 512/512 [==============================] - 0s 450us/step - loss: 0.4659 - binary_accuracy: 0.7891
# Epoch 8/100
# 512/512 [==============================] - 0s 296us/step - loss: 0.4477 - binary_accuracy: 0.8086
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.8981516290726818
# 0.06210193838562177

# %% [markdown]
# ### Melhor configuração até agora:
# - Configuração do Terceiro teste com random uniform

# %% [markdown]
# ### Sétimo Teste: Testar otimizadores
# - 1º: adamax
# - 2º: sgd
# - 3º: adagrad

# %% [markdown]
# - 1º: adamax

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adamax(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 0s 940us/step - loss: 0.6541 - binary_accuracy: 0.6777
# Epoch 2/100
# 512/512 [==============================] - 0s 301us/step - loss: 0.6165 - binary_accuracy: 0.6758
# Epoch 3/100
# 512/512 [==============================] - 0s 254us/step - loss: 0.5856 - binary_accuracy: 0.6758
# Epoch 4/100
# 512/512 [==============================] - 0s 283us/step - loss: 0.5576 - binary_accuracy: 0.6758
# Epoch 5/100
# 512/512 [==============================] - 0s 281us/step - loss: 0.5562 - binary_accuracy: 0.6758
# Epoch 6/100
# 512/512 [==============================] - 0s 254us/step - loss: 0.5406 - binary_accuracy: 0.6758
# Epoch 7/100
# 512/512 [==============================] - 0s 277us/step - loss: 0.5340 - binary_accuracy: 0.6758
# Epoch 8/100
# 512/512 [==============================] - 0s 310us/step - loss: 0.5467 - binary_accuracy: 0.6758
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.8964285714285714
# 0.06291928037366354

# %% [markdown]
# - 2º: Sgd

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.sgd(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.7004 - binary_accuracy: 0.4551
# Epoch 2/100
# 512/512 [==============================] - 0s 248us/step - loss: 0.6976 - binary_accuracy: 0.5625
# Epoch 3/100
# 512/512 [==============================] - 0s 250us/step - loss: 0.6913 - binary_accuracy: 0.6367
# Epoch 4/100
# 512/512 [==============================] - 0s 276us/step - loss: 0.6889 - binary_accuracy: 0.6426
# Epoch 5/100
# 512/512 [==============================] - 0s 265us/step - loss: 0.6857 - binary_accuracy: 0.6777
# Epoch 6/100
# 512/512 [==============================] - 0s 261us/step - loss: 0.6841 - binary_accuracy: 0.6738
# Epoch 7/100
# 512/512 [==============================] - 0s 262us/step - loss: 0.6828 - binary_accuracy: 0.6660
# Epoch 8/100
# 512/512 [==============================] - 0s 265us/step - loss: 0.6800 - binary_accuracy: 0.6699
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.7822368421052632
# 0.1280898882329455

# %% [markdown]
# - 3º: Adagrad

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adagrad(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 0.6721 - binary_accuracy: 0.5957
# Epoch 2/100
# 512/512 [==============================] - 0s 241us/step - loss: 0.6441 - binary_accuracy: 0.6387
# Epoch 3/100
# 512/512 [==============================] - 0s 241us/step - loss: 0.6290 - binary_accuracy: 0.6523
# Epoch 4/100
# 512/512 [==============================] - 0s 240us/step - loss: 0.6218 - binary_accuracy: 0.6465
# Epoch 5/100
# 512/512 [==============================] - 0s 234us/step - loss: 0.6177 - binary_accuracy: 0.6641
# Epoch 6/100
# 512/512 [==============================] - 0s 236us/step - loss: 0.5941 - binary_accuracy: 0.6680
# Epoch 7/100
# 512/512 [==============================] - 0s 238us/step - loss: 0.5979 - binary_accuracy: 0.6719
# Epoch 8/100
# 512/512 [==============================] - 0s 237us/step - loss: 0.5771 - binary_accuracy: 0.6738
# Epoch 9/100
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.6943609022556391
# 0.12505794788750776

# %% [markdown]
# ### Não houve melhorias: Configuração do terceiro teste continua sendo o melhor ate aqui

# %% [markdown]
# ### Oitavo teste: Testar a configuração dos parâmetros learning rate, decay, clipvalue e batch size
# - aumentar learning rate e o aumentar o decay.
# - aumentar numero de epocas

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 32, activation = 'relu', 
                        kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.15))
    classificador.add(Dense(units = 8, activation = 'relu', 
                        kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.1275))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.00001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy',
                      metrics = ['binary_accuracy'])
    return classificador
classificador =  KerasClassifier(build_fn = criarRede, epochs = 200, batch_size = 10)
resultados = cross_val_score(estimator = classificador,
                             X = previsores, y = classe,
                             cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/200
# 512/512 [==============================] - 1s 2ms/step - loss: 0.6487 - binary_accuracy: 0.6875
# Epoch 2/200
# 512/512 [==============================] - 0s 487us/step - loss: 0.5415 - binary_accuracy: 0.6562
# Epoch 3/200
# 512/512 [==============================] - 0s 474us/step - loss: 0.5256 - binary_accuracy: 0.7012
# Epoch 4/200
# 512/512 [==============================] - 0s 452us/step - loss: 0.5094 - binary_accuracy: 0.7129
# Epoch 5/200
# 512/512 [==============================] - 0s 404us/step - loss: 0.5117 - binary_accuracy: 0.7285
# Epoch 6/200
# 512/512 [==============================] - 0s 406us/step - loss: 0.4826 - binary_accuracy: 0.7734
# Epoch 7/200
# 512/512 [==============================] - 0s 391us/step - loss: 0.4847 - binary_accuracy: 0.7598
# Epoch 8/200
# 512/512 [==============================] - 0s 379us/step - loss: 0.4632 - binary_accuracy: 0.7969
# Epoch 9/200
# ...

# %%
print(resultados.mean())
print(resultados.std())
# Out:
# 0.9157581453634085
# 0.04689975186791319
