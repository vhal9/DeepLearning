# %% [markdown]
# ### Validação Cruzada para a base de cancer de mama

# %%
import pandas
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Carregar base de dados

# %%
previsores = pandas.read_csv('../../data/base breast cancer/entradas-breast.csv')

# %% [markdown]
# ### Estrutura da rede

# %%
classes = pandas.read_csv('../../data/base breast cancer/saidas-breast.csv')

# %%
def criarRede():
    classificador = Sequential()
    classificador.add(Dense(units = 16, activation = 'relu', kernel_initializer = 'random_uniform', input_dim = 30))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 16, activation = 'relu', kernel_initializer = 'random_uniform'))
    classificador.add(Dropout(0.2))
    classificador.add(Dense(units = 1, activation = 'sigmoid'))
    otimizador = keras.optimizers.Adam(lr = 0.001, decay = 0.0001, clipvalue = 0.5)
    classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy', metrics=['binary_accuracy'])
    return classificador

# %% [markdown]
# ### Treinamento do modelo

# %%
classificador =  KerasClassifier(build_fn = criarRede, epochs = 100, batch_size = 10)

# %%
resultados = cross_val_score(estimator = classificador, X = previsores, y = classes, cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 512/512 [==============================] - 1s 1ms/step - loss: 1.3111 - binary_accuracy: 0.5898
# Epoch 2/100
# 512/512 [==============================] - 0s 346us/step - loss: 0.8826 - binary_accuracy: 0.6582
# Epoch 3/100
# 512/512 [==============================] - 0s 386us/step - loss: 0.7254 - binary_accuracy: 0.6660
# Epoch 4/100
# 512/512 [==============================] - 0s 355us/step - loss: 0.6553 - binary_accuracy: 0.7207
# Epoch 5/100
# 512/512 [==============================] - 0s 371us/step - loss: 0.6474 - binary_accuracy: 0.7480
# Epoch 6/100
# 512/512 [==============================] - 0s 397us/step - loss: 0.8207 - binary_accuracy: 0.7031
# Epoch 7/100
# 512/512 [==============================] - 0s 436us/step - loss: 0.6204 - binary_accuracy: 0.7305
# Epoch 8/100
# 512/512 [==============================] - 0s 363us/step - loss: 0.6180 - binary_accuracy: 0.7344
# Epoch 9/100
# ...

# %% [markdown]
# #### Resultados

# %%
resultados
# Out:
# array([0.73684211, 0.84210526, 0.87719298, 0.84210526, 0.9122807 ,
#        0.87719298, 0.9122807 , 0.96491228, 0.85964912, 0.94642857])

# %%
media = resultados.mean()

# %%
desvio_padrao = resultados.std()

# %%
media
# Out:
# 0.8770989974937343

# %%
desvio_padrao
# Out:
# 0.06117099120969719
