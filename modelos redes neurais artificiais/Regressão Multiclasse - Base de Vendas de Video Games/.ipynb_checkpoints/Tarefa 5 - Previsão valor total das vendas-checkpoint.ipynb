# %%
import pandas as pd

# %%
from keras.layers import Dense, Dropout, Activation, Input
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
base = pd.read_csv('../../data/video-games-sales/Video_Games_Sales_as_at_22_Dec_2016.csv')

# %% [markdown]
# ### Preprocessamento da base de dados
# - Remover ruidos e informações irrelevantes

# %%
base
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
base = base.drop('Other_Sales', axis=1)
base = base.drop('Developer', axis=1)
base = base.drop('NA_Sales', axis=1)
base = base.drop('EU_Sales', axis=1)
base = base.drop('JP_Sales', axis=1)

# %%
base
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %% [markdown]
# ### Tratamento de valores nulos
# - deletar registro com valores nulos

# %%
base = base.dropna(axis=0)

# %%
base['Name'].value_counts()
# Out:
# Madden NFL 07                                                8
# LEGO Star Wars II: The Original Trilogy                      8
# Need for Speed: Most Wanted                                  8
# Need for Speed Carbon                                        7
# Harry Potter and the Order of the Phoenix                    7
# Madden NFL 08                                                7
# Tomb Raider: Legend                                          7
# Need for Speed: ProStreet                                    7
# Spider-Man 3                                                 7
# Terraria                                                     7
# The Sims 2                                                   7
# FIFA Soccer 09                                               6
# LEGO Marvel Super Heroes                                     6
# Spider-Man: Web of Shadows                                   6
# Peter Jackson's King Kong: The Official Game of the Movie    6
# ...

# %%
nome_jogos = base.Name

# %%
base = base.drop('Name', axis=1)

# %%
base[:10]
# Out:
#    Platform  Year_of_Release     Genre               Publisher  Global_Sales  \
# 0       Wii           2006.0    Sports                Nintendo         82.53
# 2       Wii           2008.0    Racing                Nintendo         35.52
# 3       Wii           2009.0    Sports                Nintendo         32.77
# 6        DS           2006.0  Platform                Nintendo         29.80
# 7       Wii           2006.0      Misc                Nintendo         28.92
# 8       Wii           2009.0  Platform                Nintendo         28.32
# 11       DS           2005.0    Racing                Nintendo         23.21
# 13      Wii           2007.0    Sports                Nintendo         22.70
# 14     X360           2010.0      Misc  Microsoft Game Studios         21.81
# 15      Wii           2009.0    Sports                Nintendo         21.79
#
#     Critic_Score  Critic_Count User_Score  User_Count Rating
# 0           76.0          51.0          8       322.0      E
# ...

# %% [markdown]
# ### Extrair Previsores e as classes

# %%
previsores = base.iloc[:,[0,1,2,3,5,6,7,8,9]].values

# %%
vendas_global = base.iloc[:,4].values

# %%
previsores
# Out:
# array([['Wii', 2006.0, 'Sports', ..., '8', 322.0, 'E'],
#        ['Wii', 2008.0, 'Racing', ..., '8.3', 709.0, 'E'],
#        ['Wii', 2009.0, 'Sports', ..., '8', 192.0, 'E'],
#        ...,
#        ['PC', 2014.0, 'Action', ..., '7.6', 412.0, 'M'],
#        ['PC', 2011.0, 'Shooter', ..., '5.8', 43.0, 'T'],
#        ['PC', 2011.0, 'Strategy', ..., '7.2', 13.0, 'E10+']], dtype=object)

# %% [markdown]
# - Transformação dos dados

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label_encoder = LabelEncoder()

# %%
previsores[:,0] = label_encoder.fit_transform(previsores[:,0])

# %%
previsores[:,2] = label_encoder.fit_transform(previsores[:,2])
previsores[:,3] = label_encoder.fit_transform(previsores[:,3])
previsores[:,8] = label_encoder.fit_transform(previsores[:,8])

# %% [markdown]
#  - Categorização

# %%
from sklearn.compose import ColumnTransformer

# %%
# s 1 0
# r 0 1
ct = ColumnTransformer([("", OneHotEncoder(),[0,2,3,8])], remainder="passthrough") # The last arg ([0]) is the list of columns you want to transform in this step
previsores = ct.fit_transform(previsores)

# %%
previsores
# Out:
# <6825x303 sparse matrix of type '<class 'numpy.float64'>'
# 	with 61425 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Criação da rede neural

# %%
camada_entrada = Input(shape=(303,))
camada_oculta1 = Dense(units=152, Activation('sigmoid'))(camada_entrada)
camada_oculta2 = Dense(units=152, Activation('sigmoid')(camada_oculta1)
camada_saida = Dense(units=1, Activation('linear'))(camada_oculta2)

# %%
regressor = Model(inputs = camada_entrada, outputs = camada_saida)

# %%
regressor.compile(optimizer = 'adam', loss='mse')

# %%
regressor.fit(previsores, vendas_global, epochs = 100, batch_size = 100)
# Out:
# Epoch 1/100
# 6825/6825 [==============================] - 0s 71us/step - loss: 3.8417
# Epoch 2/100
# 6825/6825 [==============================] - 0s 52us/step - loss: 3.4075
# Epoch 3/100
# 6825/6825 [==============================] - 0s 51us/step - loss: 3.4066
# Epoch 4/100
# 6825/6825 [==============================] - 0s 51us/step - loss: 3.4022
# Epoch 5/100
# 6825/6825 [==============================] - 0s 47us/step - loss: 3.4139
# Epoch 6/100
# 6825/6825 [==============================] - 0s 53us/step - loss: 3.4180
# Epoch 7/100
# 6825/6825 [==============================] - 0s 53us/step - loss: 3.4113
# Epoch 8/100
# 6825/6825 [==============================] - 0s 54us/step - loss: 3.3935
# Epoch 9/100
# 6825/6825 [==============================] - 0s 54us/step - loss: 3.3964
# Epoch 10/100
# 6825/6825 [==============================] - 0s 51us/step - loss: 3.4011
# Epoch 11/100
# 6825/6825 [==============================] - 0s 50us/step - loss: 3.3907
# Epoch 12/100
# ...

# %%
previsoes = regressor.predict(previsores)

# %%
previsoes.mean()
# Out:
# 0.8355176

# %%
vendas_global.mean()
# Out:
# 0.7775897435897436
